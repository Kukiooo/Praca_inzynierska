# %% [markdown]
# # 1. Dependencies

# %%
import numpy as np
import os
import mmengine
import pickle
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Install mmaction2 toolkit

# %% [markdown]
# ## 2.1 Install mmaction2

# %%
# !git clone https://github.com/open-mmlab/mmaction2.git
# !cd mmaction2
# !pip install -v -e .
# Out:
# Cloning into 'mmaction2'...
# Using pip 23.3.1 from C:\miniconda3\envs\openmmlab\lib\site-packages\pip (python 3.8)
# Obtaining file:///C:/Users/Kuba/Thesis
# ERROR: file:///C:/Users/Kuba/Thesis does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %% [markdown]
# ## 2.2 Copy custom configs and data

# %%
# !xcopy data mmaction2\tools\data /E /Y
# !xcopy custom_configs\MCFS-4-2s-agcn.py mmaction2\configs\skeleton\2s-agcn /Y
# !xcopy custom_configs\MCFS-4-stgcn.py mmaction2\configs\skeleton\stgcn /Y
# !xcopy custom_configs\MCFS-4-stgcnpp.py mmaction2\configs\skeleton\stgcnpp /Y
# !xcopy custom_configs\MCFS-4-posec3d.py mmaction2\configs\skeleton\posec3d /Y

# %% [markdown]
# # 3. Train models
#
# 1. Train STGCN
# 2. Train STGCNPP
# 3. Train AAGCN
# 4. Train PoseC3D

# %% [markdown]
# ## 3.1 Train STGCN

# %%
# %cd mmaction2 
# !python train.py configs/skeleton/stgcn/MCFS-4-stgcn.py
#Specify learning rate, batch size, momentum, weight_decay
#lower batch size works better because there's less noise in data?

# %% [markdown]
# ## 3.2 Train STGCNPP

# %%
# !python train.py configs/skeleton/stgcnpp/MCFS-4-stgcnpp.py

# %% [markdown]
# ## 3.3 Train AAGCN

# %%
# !python train.py configs/skeleton/s2-agcn/MCFS-4-2s-agcn.py

# %% [markdown]
# ## 3.4 Train PoseC3D

# %%
# !python train.py configs/skeleton/posec3d/MCFS-4-posec3d.py
# Out:
# ^C

# %% [markdown]
# # 4. Evaluate Models
# 1. Test models
# 2. Eval_metric
# 3. Get FLOPs
# 4. Confusion Matrix

# %% [markdown]
# ## 4.1 Test on new data

# %%
# %cd mmaction2
# !python test.py configs/skeleton/stgcn/MCFS-4-stgcn.py work_dirs/MCFS-4-stgcn/epoch_15.pth --work-dir work_dirs/MCFS-4-stgcn --dump work_dirs/MCFS-4-stgcn/results.pkl
# Out:
# [WinError 2] The system cannot find the file specified: 'mmaction2'
# C:\Users\Kuba\Thesis\mmaction2
# 01/10 01:06:33 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: win32
#     Python: 3.8.18 (default, Sep 11 2023, 13:39:12) [MSC v.1916 64 bit (AMD64)]
#     CUDA available: True
#     numpy_random_seed: 1642196778
#     GPU 0: NVIDIA GeForce RTX 2070
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3
#     NVCC: Cuda compilation tools, release 12.3, V12.3.103
#     MSVC: Microsoft (R) C/C++ wersja kompilatora optymalizujĄcego 19.31.31107 dla x64
#     GCC: n/a
#     PyTorch: 2.1.2+cu118
#     PyTorch compiling details: PyTorch built with:
#   - C++ Version: 199711
#   - MSVC 192930151
#   - Intel(R) Math Kernel Library Version 2020.0.2 Product Build 20200624 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
# ...

# %%
# !python test.py configs/skeleton/stgcnpp/MCFS-4-stgcnpp.py work_dirs/MCFS-4-stgcnpp/epoch_15.pth --work-dir work_dirs/MCFS-4-stgcnpp --dump work_dirs/MCFS-4-stgcnpp/results.pkl
# Out:
# 01/09 16:28:59 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: win32
#     Python: 3.8.18 (default, Sep 11 2023, 13:39:12) [MSC v.1916 64 bit (AMD64)]
#     CUDA available: True
#     numpy_random_seed: 988454482
#     GPU 0: NVIDIA GeForce RTX 2070
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3
#     NVCC: Cuda compilation tools, release 12.3, V12.3.103
#     MSVC: Microsoft (R) C/C++ wersja kompilatora optymalizujĄcego 19.31.31107 dla x64
#     GCC: n/a
#     PyTorch: 2.1.2+cu118
#     PyTorch compiling details: PyTorch built with:
#   - C++ Version: 199711
#   - MSVC 192930151
#   - Intel(R) Math Kernel Library Version 2020.0.2 Product Build 20200624 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
#   - CPU capability usage: AVX2
# ...

# %%
# !python test.py configs/skeleton/2s-agcn/MCFS-4-2s-agcn.py work_dirs/MCFS-4-2s-agcn/epoch_16.pth --work-dir work_dirs/MCFS-4-2s-agcn --dump work_dirs/MCFS-4-2s-agcn/results.pkl
# Out:
# 01/09 16:30:32 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: win32
#     Python: 3.8.18 (default, Sep 11 2023, 13:39:12) [MSC v.1916 64 bit (AMD64)]
#     CUDA available: True
#     numpy_random_seed: 299522035
#     GPU 0: NVIDIA GeForce RTX 2070
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3
#     NVCC: Cuda compilation tools, release 12.3, V12.3.103
#     MSVC: Microsoft (R) C/C++ wersja kompilatora optymalizujĄcego 19.31.31107 dla x64
#     GCC: n/a
#     PyTorch: 2.1.2+cu118
#     PyTorch compiling details: PyTorch built with:
#   - C++ Version: 199711
#   - MSVC 192930151
#   - Intel(R) Math Kernel Library Version 2020.0.2 Product Build 20200624 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
#   - CPU capability usage: AVX2
# ...

# %%
# !python test.py configs/skeleton/posec3d/MCFS-4-posec3d.py work_dirs/MCFS-4-posec3d/epoch_5.pth --work-dir work_dirs/MCFS-4-posec3d --dump work_dirs/MCFS-4-posec3d/results.pkl
# Out:
# 01/09 16:36:28 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: win32
#     Python: 3.8.18 (default, Sep 11 2023, 13:39:12) [MSC v.1916 64 bit (AMD64)]
#     CUDA available: True
#     numpy_random_seed: 1973655107
#     GPU 0: NVIDIA GeForce RTX 2070
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.3
#     NVCC: Cuda compilation tools, release 12.3, V12.3.103
#     MSVC: Microsoft (R) C/C++ wersja kompilatora optymalizujĄcego 19.31.31107 dla x64
#     GCC: n/a
#     PyTorch: 2.1.2+cu118
#     PyTorch compiling details: PyTorch built with:
#   - C++ Version: 199711
#   - MSVC 192930151
#   - Intel(R) Math Kernel Library Version 2020.0.2 Product Build 20200624 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
#   - CPU capability usage: AVX2
# ...

# %% [markdown]
# ## 4.2 Eval_metric

# %%
# %cd mmaction2
# !python eval_metric.py configs/skeleton/stgcn/MCFS-4-stgcn.py work_dirs/MCFS-4-stgcn/results.pkl
# !python eval_metric.py configs/skeleton/stgcnpp/MCFS-4-stgcnpp.py work_dirs/MCFS-4-stgcnpp/results.pkl
# !python eval_metric.py configs/skeleton/2s-agcn/MCFS-4-2s-agcn.py work_dirs/MCFS-4-2s-agcn/results.pkl
# !python eval_metric.py configs/skeleton/posec3d/MCFS-4-posec3d.py work_dirs/MCFS-4-posec3d/results.pkl
# Out:
# [WinError 2] The system cannot find the file specified: 'mmaction2'
# C:\Users\Kuba\Thesis\mmaction2
# {
#     'acc/top1': 0.926015767131595,
#     'acc/top5': 1.0,
#     'acc/mean1': 0.8423631637193197,
#     'acc/mean_average_precision': 0.38486108731647517
# }
# {
#     'acc/top1': 0.9393571861734384,
#     'acc/top5': 1.0,
#     'acc/mean1': 0.8623261619158039,
#     'acc/mean_average_precision': 0.39009098608032666
# }
# {
#     'acc/top1': 0.9351121892055791,
#     'acc/top5': 1.0,
#     'acc/mean1': 0.856044801231034,
#     'acc/mean_average_precision': 0.3799419784516856
# }
# {
#     'acc/top1': 0.9484536082474226,
#     'acc/top5': 1.0,
#     'acc/mean1': 0.9309981842743043,
#     'acc/mean_average_precision': 0.3821758163789987
# }

# %% [markdown]
# ## 4.3 Get Flops

# %%
# !python get_flops.py configs/skeleton/stgcn/MCFS-4-stgcn.py --shape 1 1 100 25 3
# Out:
# 01/13 02:07:06 - mmengine - WARNING - Unsupported operator aten::mul encountered 14 time(s)
# 01/13 02:07:06 - mmengine - WARNING - Unsupported operator aten::add encountered 20 time(s)
# 01/13 02:07:06 - mmengine - WARNING - Unsupported operator aten::dropout_ encountered 12 time(s)
# 01/13 02:07:06 - mmengine - WARNING - The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# cls_head, cls_head.fc, cls_head.loss_cls, cls_head.pool, data_preprocessor
# 01/13 02:07:06 - mmengine - WARNING - Unsupported operator aten::batch_norm encountered 23 time(s)
#
# +---------------------------+----------------------+-----------+--------------+
# | module                    | #parameters or shape | #flops    | #activations |
# ...

# %%
#!python get_flops.py configs/skeleton/posec3d/MCFS-4-posec3d.py --shape 1 25 48 720 1080

# %%
# !python get_flops.py configs/skeleton/stgcnpp/MCFS-4-stgcnpp.py --shape 1 1 100 25 3
# Out:
# 01/13 02:07:16 - mmengine - WARNING - Unsupported operator aten::mul encountered 4 time(s)
# 01/13 02:07:16 - mmengine - WARNING - Unsupported operator aten::add encountered 20 time(s)
# 01/13 02:07:16 - mmengine - WARNING - Unsupported operator aten::dropout_ encountered 52 time(s)
# 01/13 02:07:16 - mmengine - WARNING - Unsupported operator aten::max_pool2d encountered 10 time(s)
# 01/13 02:07:16 - mmengine - WARNING - The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# cls_head, cls_head.fc, cls_head.loss_cls, cls_head.pool, data_preprocessor
# 01/13 02:07:17 - mmengine - WARNING - Unsupported operator aten::batch_norm encountered 86 time(s)
#
# ...

# %%
# !python get_flops.py configs/skeleton/2s-agcn/MCFS-4-2s-agcn.py --shape 1 1 100 25 3
# Out:
# 01/13 02:07:27 - mmengine - WARNING - Unsupported operator aten::mul encountered 124 time(s)
# 01/13 02:07:27 - mmengine - WARNING - Unsupported operator aten::div encountered 30 time(s)
# 01/13 02:07:27 - mmengine - WARNING - Unsupported operator aten::tanh encountered 30 time(s)
# 01/13 02:07:27 - mmengine - WARNING - Unsupported operator aten::add encountered 70 time(s)
# 01/13 02:07:27 - mmengine - WARNING - Unsupported operator aten::dropout_ encountered 12 time(s)
# 01/13 02:07:27 - mmengine - WARNING - The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# ...

# %% [markdown]
# ## 4.4 Confusion matrix

# %%
# %cd mmaction2
# !python confusion_matrix.py configs/skeleton/stgcn/MCFS-4-stgcn.py work_dirs/MCFS-4-stgcn/results.pkl --show-path work_dirs/MCFS-4-stgcn/conf.png --include-values --target-classes 0 1 2 3
# Out:
# C:\Users\Kuba\Thesis\mmaction2
# 01/13 03:24:50 - mmengine - INFO - 1649 videos remain after valid thresholding
# The confusion matrix is saved at work_dirs/MCFS-4-stgcn/conf.png.

# %%
# %cd mmaction2
# !python confusion_matrix.py configs/skeleton/stgcnpp/MCFS-4-stgcnpp.py work_dirs/MCFS-4-stgcnpp/results.pkl --show-path work_dirs/MCFS-4-stgcnpp/conf.png --include-values --target-classes 0 1 2 3
# Out:
# C:\Users\Kuba\Thesis\mmaction2
# 01/13 08:41:46 - mmengine - INFO - 1649 videos remain after valid thresholding
# The confusion matrix is saved at work_dirs/MCFS-4-stgcnpp/conf.png.

# %%
# !python confusion_matrix.py configs/skeleton/2s-agcn/MCFS-4-2s-agcn.py work_dirs/MCFS-4-2s-agcn/results.pkl --show-path work_dirs/MCFS-4-2s-agcn/conf.png --include-values --target-classes 0 1 2 3
# Out:
# 01/13 08:48:59 - mmengine - INFO - 1649 videos remain after valid thresholding
# The confusion matrix is saved at work_dirs/MCFS-4-2s-agcn/conf.png.

# %%
# !python confusion_matrix.py configs/skeleton/posec3d/MCFS-4-posec3d.py work_dirs/MCFS-4-posec3d/results.pkl --show-path work_dirs/MCFS-4-posec3d/conf.png --include-values --target-classes 0 1 2 3
# Out:
# 01/13 08:51:33 - mmengine - INFO - 1649 videos remain after valid thresholding
# The confusion matrix is saved at work_dirs/MCFS-4-posec3d/conf.png.
